# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
results = []
for file in os.listdir('../../results_temp/within_county/within_county_full_preprocessing/'):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join('../../results_temp/within_county/within_county_full_preprocessing/', file))
        results.append(df)

results = pd.concat(results)

# %%
results
# Out:
#       model  train_size  test_size  n_features   fit_time  pred_time  \
# 0    tabpfn          68         18          39  20.033209   5.687219
# 1   xgboost          68         18          39   6.724500   0.002654
# 2    tabpfn          69         17          39   0.271396   0.135526
# 3   xgboost          69         17          39   5.951883   0.002534
# 4    tabpfn          69         17          39   0.273096   0.136369
# ..      ...         ...        ...         ...        ...        ...
# 95  xgboost          59         15          42   7.107626   0.003612
# 96   tabpfn          59         15          42   0.451524   0.225034
# 97  xgboost          59         15          42   6.283143   0.003583
# 98   tabpfn          60         14          42   0.437146   0.221308
# 99  xgboost          60         14          42  10.572764   0.003762
#
#           r2           mae           rmse           mse  ...  \
# 0   0.465360  38218.585503   59102.841065  3.493146e+09  ...
# ...

# %%
df1 = results[results['model'] == 'tabpfn']
df2 = results[results['model'] == 'xgboost']

# %%
df1['mae'].describe()
# Out:
# count       150.000000
# mean      70059.538834
# std       30544.152383
# min        2442.690104
# 25%       50134.145461
# 50%       63107.966806
# 75%       82808.879643
# max      174053.100260
# Name: mae, dtype: float64

# %%
df2['mae'].describe()
# Out:
# count       150.000000
# mean      76596.744662
# std       36572.552451
# min       20063.752604
# 25%       51561.556827
# 50%       67490.745996
# 75%       92109.521054
# max      228616.334635
# Name: mae, dtype: float64
